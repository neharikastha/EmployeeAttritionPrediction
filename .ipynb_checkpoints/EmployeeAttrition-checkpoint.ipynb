# %% [markdown]
# # Importing the necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading dataset

# %%
df=pd.read_csv('Datasets/Employee_Attrition_Data.csv')

# %% [markdown]
# # Data Exploration and Initial Exploration

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# # removing the constant features

# %%
constant_features = [col for col in df.columns if df[col].nunique() == 1]
constant_features
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df = df.drop(columns=constant_features)
print("Removed constant features:", constant_features)
# Out:
# Removed constant features: ['EmployeeCount', 'Over18', 'StandardHours']

# %% [markdown]
# # Describing summary of the datasets

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  JobSatisfaction  ...  PerformanceRating  \
# count  1470.000000      1470.000000  ...        1470.000000
# mean      2.063946         2.728571  ...           3.153741
# std       1.106940         1.102846  ...           0.360824
# min       1.000000         1.000000  ...           3.000000
# 25%       1.000000         2.000000  ...           3.000000
# 50%       2.000000         3.000000  ...           3.000000
# 75%       3.000000         4.000000  ...           3.000000
# max       5.000000         4.000000  ...           4.000000
#
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count               1470.000000       1470.000000        1470.000000
# mean                   2.712245          0.793878          11.279592
# std                    1.081209          0.852077           7.780782
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000          10.000000
# 75%                    4.000000          1.000000          15.000000
# max                    4.000000          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# # Vision over columns in the dataset

# %%
list(df.columns)
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %% [markdown]
# # Finding the missing values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Listing the categorical and numerical columns

# %%
categorical_columns=df.select_dtypes(include=['category','object']).columns
numerical_columns=df.select_dtypes(exclude=['category','object']).columns

# %% [markdown]
# # There are no missing columns

# %%
df[categorical_columns].isnull().sum()
# Out:
# Attrition         0
# BusinessTravel    0
# Department        0
# EducationField    0
# Gender            0
# JobRole           0
# MaritalStatus     0
# OverTime          0
# dtype: int64

# %%
df[numerical_columns].isnull().sum()
# Out:
# Age                         0
# DailyRate                   0
# DistanceFromHome            0
# Education                   0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobSatisfaction             0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Plotting Boxplot of numerical columns

# %%
plt.figure(figsize=(30,6))
sns.boxplot(data=df[numerical_columns])
plt.xticks(rotation=45)
plt.title('Box plot of numerical columns')
plt.show()

# %% [markdown]
# #### To determine whether numerical columns follow a normal distribution, you can perform statistical tests or visual inspections. Normal distribution, also known as Gaussian distribution, is characterized by a bell-shaped curve where the data cluster around the mean, with most values close to the mean and fewer values farther away.

# %%
import scipy.stats as stats

# %% [markdown]
# # Create a figure and axes for subplots

# %%
num_cols=len(numerical_columns)
fig, axes= plt.subplots(num_cols, 2, figsize=(16, num_cols*4))

# plotting histogram and Q-Q plots for each numerical column

for i, col in enumerate(numerical_columns):
        #Hitogram on the left subplot
    sns.histplot(df[col], kde=True, ax=axes[i,0], stat='density', linewidth=0.5)
    axes[i,0].set_title(f'histogram of {col}')
    axes[i,0].set_xlabel('')
    axes[i,0].set_ylabel('Density')
    axes[i,0].grid(True, linestyle='--', alpha=0.7)

    #Q-Q plot on the right subplot
    stats.probplot(df[col], plot=axes[i,1], dist='norm', fit=True)
    axes[i,1].get_lines()[0].set_markersize(2.0)
    axes[i,1].grid(True,linestyle='--', alpha=0.7)
    axes[i,1].set_title(f'Q-Q Plot for {col}')
    axes[i,1].set_xlabel('Theoritical Quantiles')
    axes[i,1].set_ylabel('Practical Quantile')
plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# #### Statistical Tests: Use statistical methods such as the Shapiro-Wilk test or Kolmogorov-Smirnov test. These tests evaluate whether a sample of data comes from a normal distribution. If the p-value from these tests is greater than a chosen significance level (e.g., 0.05), it suggests that the data may follow a normal distribution.
# #### Descriptive Statistics: Calculate descriptive statistics such as mean, median, and standard deviation. For normally distributed data, the mean and median are typically close in value, and about 68% of the data falls within one standard deviation of the mean, 95% within two standard deviations, and 99.7% within three standard deviations.

# %%
from scipy.stats import anderson, jarque_bera, shapiro, normaltest, kstest
from statsmodels.stats.diagnostic import lilliefors

# %% [markdown]
# # Function to perform normality tests

# %%
def test_normality(df, col):
    print(f'Column: {col}')
    
    # Shapiro-Wilk test
    stat_shapiro, p_shapiro = shapiro(df[col])
    print(f'Shapiro-Wilk Test: Statistics={stat_shapiro:.3f}, p-value={p_shapiro:.3f}')
    if p_shapiro > 0.05:
        print(f'Shapiro-Wilk Test: {col} looks normally distributed (fail to reject H0)')
    else:
        print(f'Shapiro-Wilk Test: {col} does not look normally distributed (reject H0)')
    
    # Anderson-Darling test
    result_anderson = anderson(df[col])
    print(f'Anderson-Darling Test: Statistics={result_anderson.statistic:.3f}')
    print(f'Anderson-Darling Test: Critical Values: {result_anderson.critical_values}')
    if result_anderson.statistic < result_anderson.critical_values[2]:
        print(f'Anderson-Darling Test: {col} looks normally distributed (fail to reject H0)')
    else:
        print(f'Anderson-Darling Test: {col} does not look normally distributed (reject H0)')
    
    # Jarque-Bera test
    jb_stat, p_val_jb = jarque_bera(df[col])
    print(f'Jarque-Bera Test: JB statistic={jb_stat:.3f}, p-value={p_val_jb:.3f}')
    if p_val_jb > 0.05:
        print(f'Jarque-Bera Test: {col} looks normally distributed (fail to reject H0)')
    else:
        print(f'Jarque-Bera Test: {col} does not look normally distributed (reject H0)')


# D'Agostino and Pearson's test
    stat_agostino, p_agostino = normaltest(df[col])
    print(f"D'Agostino and Pearson's Test: Statistics={stat_agostino:.3f}, p-value={p_agostino:.3f}")
    if p_agostino > 0.05:
        print(f"D'Agostino and Pearson's Test: {col} looks normally distributed (fail to reject H0)")
    else:
        print(f"D'Agostino and Pearson's Test: {col} does not look normally distributed (reject H0)")
    
    # Kolmogorov-Smirnov test
    ks_stat, p_ks = kstest(df[col], 'norm')
    print(f'Kolmogorov-Smirnov Test: KS statistic={ks_stat:.3f}, p-value={p_ks:.3f}')
    if p_ks > 0.05:
        print(f'Kolmogorov-Smirnov Test: {col} looks normally distributed (fail to reject H0)')
    else:
        print(f'Kolmogorov-Smirnov Test: {col} does not look normally distributed (reject H0)')
    
    # Lilliefors test
    stat_lilliefors, p_lilliefors = lilliefors(df[col])
    print(f'Lilliefors Test: Statistics={stat_lilliefors:.3f}, p-value={p_lilliefors:.3f}')
    if p_lilliefors > 0.05:
        print(f'Lilliefors Test: {col} looks normally distributed (fail to reject H0)')
    else:
        print(f'Lilliefors Test: {col} does not look normally distributed (reject H0)')
    
    print('\n')

# Perform normality tests for each numerical column
for col in numerical_columns:
    test_normality(df, col)
# Out:
# Column: Age
# Shapiro-Wilk Test: Statistics=0.977, p-value=0.000
# Shapiro-Wilk Test: Age does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=9.969
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: Age does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=51.901, p-value=0.000
# Jarque-Bera Test: Age does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=54.684, p-value=0.000
# D'Agostino and Pearson's Test: Age does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: Age does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.083, p-value=0.001
# Lilliefors Test: Age does not look normally distributed (reject H0)
#
#
# Column: DailyRate
# Shapiro-Wilk Test: Statistics=0.954, p-value=0.000
# Shapiro-Wilk Test: DailyRate does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=16.829
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: DailyRate does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=88.764, p-value=0.000
# Jarque-Bera Test: DailyRate does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1179.175, p-value=0.000
# D'Agostino and Pearson's Test: DailyRate does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: DailyRate does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.071, p-value=0.001
# Lilliefors Test: DailyRate does not look normally distributed (reject H0)
#
#
# Column: DistanceFromHome
# Shapiro-Wilk Test: Statistics=0.862, p-value=0.000
# Shapiro-Wilk Test: DistanceFromHome does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=68.310
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: DistanceFromHome does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=227.637, p-value=0.000
# Jarque-Bera Test: DistanceFromHome does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=168.694, p-value=0.000
# D'Agostino and Pearson's Test: DistanceFromHome does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.841, p-value=0.000
# Kolmogorov-Smirnov Test: DistanceFromHome does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.158, p-value=0.001
# Lilliefors Test: DistanceFromHome does not look normally distributed (reject H0)
#
#
# Column: Education
# Shapiro-Wilk Test: Statistics=0.895, p-value=0.000
# Shapiro-Wilk Test: Education does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=66.054
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: Education does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=39.814, p-value=0.000
# Jarque-Bera Test: Education does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=57.818, p-value=0.000
# D'Agostino and Pearson's Test: Education does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.862, p-value=0.000
# Kolmogorov-Smirnov Test: Education does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.226, p-value=0.001
# Lilliefors Test: Education does not look normally distributed (reject H0)
#
#
# Column: EmployeeNumber
# Shapiro-Wilk Test: Statistics=0.952, p-value=0.000
# Shapiro-Wilk Test: EmployeeNumber does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=17.760
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: EmployeeNumber does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=91.696, p-value=0.000
# Jarque-Bera Test: EmployeeNumber does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1400.190, p-value=0.000
# D'Agostino and Pearson's Test: EmployeeNumber does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.999, p-value=0.000
# Kolmogorov-Smirnov Test: EmployeeNumber does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.067, p-value=0.001
# Lilliefors Test: EmployeeNumber does not look normally distributed (reject H0)
#
#
# Column: EnvironmentSatisfaction
# Shapiro-Wilk Test: Statistics=0.849, p-value=0.000
# Shapiro-Wilk Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=79.339
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=113.866, p-value=0.000
# Jarque-Bera Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1190.625, p-value=0.000
# D'Agostino and Pearson's Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.841, p-value=0.000
# Kolmogorov-Smirnov Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.212, p-value=0.001
# Lilliefors Test: EnvironmentSatisfaction does not look normally distributed (reject H0)
#
#
# Column: HourlyRate
# Shapiro-Wilk Test: Statistics=0.955, p-value=0.000
# Shapiro-Wilk Test: HourlyRate does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=16.646
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: HourlyRate does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=87.929, p-value=0.000
# Jarque-Bera Test: HourlyRate does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1108.702, p-value=0.000
# D'Agostino and Pearson's Test: HourlyRate does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: HourlyRate does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.069, p-value=0.001
# Lilliefors Test: HourlyRate does not look normally distributed (reject H0)
#
#
# Column: JobInvolvement
# Shapiro-Wilk Test: Statistics=0.809, p-value=0.000
# Shapiro-Wilk Test: JobInvolvement does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=141.458
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: JobInvolvement does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=65.073, p-value=0.000
# Jarque-Bera Test: JobInvolvement does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=58.865, p-value=0.000
# D'Agostino and Pearson's Test: JobInvolvement does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.921, p-value=0.000
# Kolmogorov-Smirnov Test: JobInvolvement does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.336, p-value=0.001
# Lilliefors Test: JobInvolvement does not look normally distributed (reject H0)
#
#
# Column: JobLevel
# Shapiro-Wilk Test: Statistics=0.822, p-value=0.000
# Shapiro-Wilk Test: JobLevel does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=94.054
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: JobLevel does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=266.574, p-value=0.000
# Jarque-Bera Test: JobLevel does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=190.080, p-value=0.000
# D'Agostino and Pearson's Test: JobLevel does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.841, p-value=0.000
# Kolmogorov-Smirnov Test: JobLevel does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.256, p-value=0.001
# Lilliefors Test: JobLevel does not look normally distributed (reject H0)
#
#
# Column: JobSatisfaction
# Shapiro-Wilk Test: Statistics=0.846, p-value=0.000
# Shapiro-Wilk Test: JobSatisfaction does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=81.178
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: JobSatisfaction does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=118.055, p-value=0.000
# Jarque-Bera Test: JobSatisfaction does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1412.870, p-value=0.000
# D'Agostino and Pearson's Test: JobSatisfaction does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.841, p-value=0.000
# Kolmogorov-Smirnov Test: JobSatisfaction does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.210, p-value=0.001
# Lilliefors Test: JobSatisfaction does not look normally distributed (reject H0)
#
#
# Column: MonthlyIncome
# Shapiro-Wilk Test: Statistics=0.828, p-value=0.000
# Shapiro-Wilk Test: MonthlyIncome does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=85.391
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: MonthlyIncome does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=519.753, p-value=0.000
# Jarque-Bera Test: MonthlyIncome does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=305.334, p-value=0.000
# D'Agostino and Pearson's Test: MonthlyIncome does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: MonthlyIncome does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.169, p-value=0.001
# Lilliefors Test: MonthlyIncome does not look normally distributed (reject H0)
#
#
# Column: MonthlyRate
# Shapiro-Wilk Test: Statistics=0.954, p-value=0.000
# Shapiro-Wilk Test: MonthlyRate does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=17.414
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: MonthlyRate does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=90.489, p-value=0.000
# Jarque-Bera Test: MonthlyRate does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1299.077, p-value=0.000
# D'Agostino and Pearson's Test: MonthlyRate does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: MonthlyRate does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.066, p-value=0.001
# Lilliefors Test: MonthlyRate does not look normally distributed (reject H0)
#
#
# Column: NumCompaniesWorked
# Shapiro-Wilk Test: Statistics=0.849, p-value=0.000
# Shapiro-Wilk Test: NumCompaniesWorked does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=83.539
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: NumCompaniesWorked does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=257.618, p-value=0.000
# Jarque-Bera Test: NumCompaniesWorked does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=183.062, p-value=0.000
# D'Agostino and Pearson's Test: NumCompaniesWorked does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.707, p-value=0.000
# Kolmogorov-Smirnov Test: NumCompaniesWorked does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.239, p-value=0.001
# Lilliefors Test: NumCompaniesWorked does not look normally distributed (reject H0)
#
#
# Column: PercentSalaryHike
# Shapiro-Wilk Test: Statistics=0.901, p-value=0.000
# Shapiro-Wilk Test: PercentSalaryHike does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=47.799
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: PercentSalaryHike does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=170.502, p-value=0.000
# Jarque-Bera Test: PercentSalaryHike does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=136.975, p-value=0.000
# D'Agostino and Pearson's Test: PercentSalaryHike does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=1.000, p-value=0.000
# Kolmogorov-Smirnov Test: PercentSalaryHike does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.186, p-value=0.001
# Lilliefors Test: PercentSalaryHike does not look normally distributed (reject H0)
#
#
# Column: PerformanceRating
# Shapiro-Wilk Test: Statistics=0.432, p-value=0.000
# Shapiro-Wilk Test: PerformanceRating does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=432.584
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: PerformanceRating does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=1077.223, p-value=0.000
# Jarque-Bera Test: PerformanceRating does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=478.814, p-value=0.000
# D'Agostino and Pearson's Test: PerformanceRating does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.999, p-value=0.000
# Kolmogorov-Smirnov Test: PerformanceRating does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.511, p-value=0.001
# Lilliefors Test: PerformanceRating does not look normally distributed (reject H0)
#
#
# Column: RelationshipSatisfaction
# Shapiro-Wilk Test: Statistics=0.853, p-value=0.000
# Shapiro-Wilk Test: RelationshipSatisfaction does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=76.850
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: RelationshipSatisfaction does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=108.411, p-value=0.000
# Jarque-Bera Test: RelationshipSatisfaction does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=1031.961, p-value=0.000
# D'Agostino and Pearson's Test: RelationshipSatisfaction does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.841, p-value=0.000
# Kolmogorov-Smirnov Test: RelationshipSatisfaction does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.211, p-value=0.001
# Lilliefors Test: RelationshipSatisfaction does not look normally distributed (reject H0)
#
#
# Column: StockOptionLevel
# Shapiro-Wilk Test: Statistics=0.790, p-value=0.000
# Shapiro-Wilk Test: StockOptionLevel does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=119.731
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: StockOptionLevel does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=237.475, p-value=0.000
# Jarque-Bera Test: StockOptionLevel does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=174.111, p-value=0.000
# D'Agostino and Pearson's Test: StockOptionLevel does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.500, p-value=0.000
# Kolmogorov-Smirnov Test: StockOptionLevel does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.254, p-value=0.001
# Lilliefors Test: StockOptionLevel does not look normally distributed (reject H0)
#
#
# Column: TotalWorkingYears
# Shapiro-Wilk Test: Statistics=0.907, p-value=0.000
# Shapiro-Wilk Test: TotalWorkingYears does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=43.524
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: TotalWorkingYears does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=355.994, p-value=0.000
# Jarque-Bera Test: TotalWorkingYears does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=233.738, p-value=0.000
# D'Agostino and Pearson's Test: TotalWorkingYears does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.915, p-value=0.000
# Kolmogorov-Smirnov Test: TotalWorkingYears does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.193, p-value=0.001
# Lilliefors Test: TotalWorkingYears does not look normally distributed (reject H0)
#
#
# Column: TrainingTimesLastYear
# Shapiro-Wilk Test: Statistics=0.895, p-value=0.000
# Shapiro-Wilk Test: TrainingTimesLastYear does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=69.288
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: TrainingTimesLastYear does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=89.464, p-value=0.000
# Jarque-Bera Test: TrainingTimesLastYear does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=76.719, p-value=0.000
# D'Agostino and Pearson's Test: TrainingTimesLastYear does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.892, p-value=0.000
# Kolmogorov-Smirnov Test: TrainingTimesLastYear does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.229, p-value=0.001
# Lilliefors Test: TrainingTimesLastYear does not look normally distributed (reject H0)
#
#
# Column: WorkLifeBalance
# Shapiro-Wilk Test: Statistics=0.802, p-value=0.000
# Shapiro-Wilk Test: WorkLifeBalance does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=147.444
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: WorkLifeBalance does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=85.126, p-value=0.000
# Jarque-Bera Test: WorkLifeBalance does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=74.138, p-value=0.000
# D'Agostino and Pearson's Test: WorkLifeBalance does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.923, p-value=0.000
# Kolmogorov-Smirnov Test: WorkLifeBalance does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.344, p-value=0.001
# Lilliefors Test: WorkLifeBalance does not look normally distributed (reject H0)
#
#
# Column: YearsAtCompany
# Shapiro-Wilk Test: Statistics=0.839, p-value=0.000
# Shapiro-Wilk Test: YearsAtCompany does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=60.711
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: YearsAtCompany does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=1701.526, p-value=0.000
# Jarque-Bera Test: YearsAtCompany does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=518.189, p-value=0.000
# D'Agostino and Pearson's Test: YearsAtCompany does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.831, p-value=0.000
# Kolmogorov-Smirnov Test: YearsAtCompany does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.156, p-value=0.001
# Lilliefors Test: YearsAtCompany does not look normally distributed (reject H0)
#
#
# Column: YearsInCurrentRole
# Shapiro-Wilk Test: Statistics=0.896, p-value=0.000
# Shapiro-Wilk Test: YearsInCurrentRole does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=50.263
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: YearsInCurrentRole does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=219.390, p-value=0.000
# Jarque-Bera Test: YearsInCurrentRole does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=164.073, p-value=0.000
# D'Agostino and Pearson's Test: YearsInCurrentRole does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.772, p-value=0.000
# Kolmogorov-Smirnov Test: YearsInCurrentRole does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.189, p-value=0.001
# Lilliefors Test: YearsInCurrentRole does not look normally distributed (reject H0)
#
#
# Column: YearsSinceLastPromotion
# Shapiro-Wilk Test: Statistics=0.704, p-value=0.000
# Shapiro-Wilk Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=157.065
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=1754.873, p-value=0.000
# Jarque-Bera Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=564.323, p-value=0.000
# D'Agostino and Pearson's Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.500, p-value=0.000
# Kolmogorov-Smirnov Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.282, p-value=0.001
# Lilliefors Test: YearsSinceLastPromotion does not look normally distributed (reject H0)
#
#
# Column: YearsWithCurrManager
# Shapiro-Wilk Test: Statistics=0.897, p-value=0.000
# Shapiro-Wilk Test: YearsWithCurrManager does not look normally distributed (reject H0)
# Anderson-Darling Test: Statistics=51.587
# Anderson-Darling Test: Critical Values: [0.574 0.654 0.785 0.916 1.089]
# Anderson-Darling Test: YearsWithCurrManager does not look normally distributed (reject H0)
# Jarque-Bera Test: JB statistic=171.536, p-value=0.000
# Jarque-Bera Test: YearsWithCurrManager does not look normally distributed (reject H0)
# D'Agostino and Pearson's Test: Statistics=134.348, p-value=0.000
# D'Agostino and Pearson's Test: YearsWithCurrManager does not look normally distributed (reject H0)
# Kolmogorov-Smirnov Test: KS statistic=0.747, p-value=0.000
# Kolmogorov-Smirnov Test: YearsWithCurrManager does not look normally distributed (reject H0)
# Lilliefors Test: Statistics=0.189, p-value=0.001
# Lilliefors Test: YearsWithCurrManager does not look normally distributed (reject H0)

# %% [markdown]
# ### doesnot look normally distributed, so uses IQR method

# %% [markdown]
# ## Function to detect outliers using IQR method

# %%
def find_outliers_iqr(data):
    outliers_mask = pd.Series(index=data.columns, dtype=bool)
    
    for col in data.columns: # process only numerical columns
        if col in numerical_columns:
            Q1 = data[col].quantile(0.25)
            Q3 = data[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            col_outliers_mask = (data[col] < lower_bound) | (data[col] > upper_bound)
            outliers_mask[col] =  col_outliers_mask.any() # True if any outliers detected
            
    return outliers_mask
    
outliers_iqr_mask = find_outliers_iqr(df)
print("Outliers detected using IQR method")
for col, is_outlier in outliers_iqr_mask.items():
    print(f" {col}: {is_outlier}")
# Out:
# Outliers detected using IQR method
#  Age: False
#  Attrition: True
#  BusinessTravel: True
#  DailyRate: False
#  Department: True
#  DistanceFromHome: False
#  Education: False
#  EducationField: True
#  EmployeeNumber: False
#  EnvironmentSatisfaction: False
#  Gender: True
#  HourlyRate: False
#  JobInvolvement: False
#  JobLevel: False
#  JobRole: True
#  JobSatisfaction: False
#  MaritalStatus: True
#  MonthlyIncome: True
#  MonthlyRate: False
#  NumCompaniesWorked: True
#  OverTime: True
#  PercentSalaryHike: False
#  PerformanceRating: True
#  RelationshipSatisfaction: False
#  StockOptionLevel: True
#  TotalWorkingYears: True
#  TrainingTimesLastYear: True
#  WorkLifeBalance: False
#  YearsAtCompany: True
#  YearsInCurrentRole: True
#  YearsSinceLastPromotion: True
#  YearsWithCurrManager: True

# %% [markdown]
# # Function to remove outliers using IQR method

# %%
def remove_outliers_iqr(data):
    cleaned_data = data.copy()

    for col in data.columns:
        if col in numerical_columns:  # Process only numerical columns
            Q1 = data[col].quantile(0.25)
            Q3 = data[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            cleaned_data = cleaned_data[(cleaned_data[col] >= lower_bound) & (cleaned_data[col] <= upper_bound)]

    return cleaned_data

cleaned_data_iqr = remove_outliers_iqr(df)
print("DataFrame after removing outliers using IQR method:")
print(cleaned_data_iqr)
# Out:
# DataFrame after removing outliers using IQR method:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 2                    2          2          Other               4
# 3                    3          4  Life Sciences               5
# 5                    2          2  Life Sciences               8
# 9                   27          3        Medical              13
# 11                  15          2  Life Sciences              15
# ...                ...        ...            ...             ...
# 1463                 5          3        Medical            2057
# 1464                 5          3          Other            2060
# 1465                23          2        Medical            2061
# 1468                 2          3        Medical            2065
# 1469                 8          3        Medical            2068
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 2                           4  ...                 3
# 3                           4  ...                 3
# 5                           4  ...                 3
# 9                           3  ...                 3
# 11                          4  ...                 3
# ...                       ...  ...               ...
# 1463                        2  ...                 3
# 1464                        4  ...                 3
# 1465                        3  ...                 3
# 1468                        4  ...                 3
# 1469                        2  ...                 3
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 2                            2                 0                  7
# 3                            3                 0                  8
# 5                            3                 0                  8
# 9                            2                 2                 17
# 11                           4                 0                 10
# ...                        ...               ...                ...
# 1463                         2                 0                 10
# 1464                         4                 0                  5
# 1465                         3                 1                 17
# 1468                         4                 0                 17
# 1469                         1                 0                  6
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 2                        3                3              0
# 3                        3                3              8
# 5                        2                2              7
# 9                        3                2              7
# 11                       3                3              9
# ...                    ...              ...            ...
# 1463                     2                3              9
# 1464                     2                3              4
# 1465                     3                3              5
# 1468                     3                2              9
# 1469                     3                4              4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 2                      0                        0                     0
# 3                      7                        3                     0
# 5                      7                        3                     6
# 9                      7                        7                     7
# 11                     5                        0                     8
# ...                  ...                      ...                   ...
# 1463                   4                        1                     7
# 1464                   2                        0                     0
# 1465                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
# [779 rows x 32 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
numeric_data = df[numerical_columns]

# computer partwise xonnections of numeric columns
correlation_matrix = numeric_data.corr()

#plotting correlation heatmap
plt.figure(figsize=(15,15))
sns.heatmap(correlation_matrix, annot= True, cmap='coolwarm', fmt=".2f", square= True)
plt.title('Correlation Matrix of Numeric features')
plt.show()

# %% [markdown]
# # Pair plot of numerical values

# %%
#sns.pairplot(df[numerical_columns],diag_kind='kde')
#plt.suptitle('Pairplot of Numerical Features', y=1.02)
#plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title("Attrition and Department")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='EducationField', hue='Attrition', data=df)
plt.title("Attrition and EducationField")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='JobRole', hue='Attrition', data=df)
plt.title("Attrition and JobRole")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title("Attrition and Gender")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Age', hue='Attrition', data=df)
plt.title("Attrition and Age")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.kdeplot(df['Age'])
plt.show()

# %%
df.to_csv('Datasets/filtered_data.csv', index=False)

# %% [markdown]
# # Loading and Working with the filtered data sets

# %%
data = pd.read_csv("Datasets/filtered_data.csv")

# %%
df.head(60)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# 12   31        No      Travel_Rarely        670  Research & Development
# 13   34        No      Travel_Rarely       1346  Research & Development
# 14   28       Yes      Travel_Rarely        103  Research & Development
# 15   29        No      Travel_Rarely       1389  Research & Development
# 16   32        No      Travel_Rarely        334  Research & Development
# 17   22        No         Non-Travel       1123  Research & Development
# 18   53        No      Travel_Rarely       1219                   Sales
# 19   38        No      Travel_Rarely        371  Research & Development
# 20   24        No         Non-Travel        673  Research & Development
# 21   36       Yes      Travel_Rarely       1218                   Sales
# 22   34        No      Travel_Rarely        419  Research & Development
# 23   21        No      Travel_Rarely        391  Research & Development
# 24   34       Yes      Travel_Rarely        699  Research & Development
# 25   53        No      Travel_Rarely       1282  Research & Development
# 26   32       Yes  Travel_Frequently       1125  Research & Development
# 27   42        No      Travel_Rarely        691                   Sales
# 28   44        No      Travel_Rarely        477  Research & Development
# 29   46        No      Travel_Rarely        705                   Sales
# 30   33        No      Travel_Rarely        924  Research & Development
# 31   44        No      Travel_Rarely       1459  Research & Development
# 32   30        No      Travel_Rarely        125  Research & Development
# 33   39       Yes      Travel_Rarely        895                   Sales
# 34   24       Yes      Travel_Rarely        813  Research & Development
# 35   43        No      Travel_Rarely       1273  Research & Development
# 36   50       Yes      Travel_Rarely        869                   Sales
# 37   35        No      Travel_Rarely        890                   Sales
# 38   36        No      Travel_Rarely        852  Research & Development
# 39   33        No  Travel_Frequently       1141                   Sales
# 40   35        No      Travel_Rarely        464  Research & Development
# 41   27        No      Travel_Rarely       1240  Research & Development
# 42   26       Yes      Travel_Rarely       1357  Research & Development
# 43   27        No  Travel_Frequently        994                   Sales
# 44   30        No  Travel_Frequently        721  Research & Development
# 45   41       Yes      Travel_Rarely       1360  Research & Development
# 46   34        No         Non-Travel       1065                   Sales
# 47   37        No      Travel_Rarely        408  Research & Development
# 48   46        No  Travel_Frequently       1211                   Sales
# 49   35        No      Travel_Rarely       1229  Research & Development
# 50   48       Yes      Travel_Rarely        626  Research & Development
# 51   28       Yes      Travel_Rarely       1434  Research & Development
# 52   44        No      Travel_Rarely       1488                   Sales
# 53   35        No         Non-Travel       1097  Research & Development
# 54   26        No      Travel_Rarely       1443                   Sales
# 55   33        No  Travel_Frequently        515  Research & Development
# 56   35        No  Travel_Frequently        853                   Sales
# 57   35        No      Travel_Rarely       1142  Research & Development
# 58   31        No      Travel_Rarely        655  Research & Development
# 59   37        No      Travel_Rarely       1115  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                  1          2     Life Sciences               1
# 1                  8          1     Life Sciences               2
# 2                  2          2             Other               4
# 3                  3          4     Life Sciences               5
# 4                  2          1           Medical               7
# 5                  2          2     Life Sciences               8
# 6                  3          3           Medical              10
# 7                 24          1     Life Sciences              11
# 8                 23          3     Life Sciences              12
# 9                 27          3           Medical              13
# 10                16          3           Medical              14
# 11                15          2     Life Sciences              15
# 12                26          1     Life Sciences              16
# 13                19          2           Medical              18
# 14                24          3     Life Sciences              19
# 15                21          4     Life Sciences              20
# 16                 5          2     Life Sciences              21
# 17                16          2           Medical              22
# 18                 2          4     Life Sciences              23
# 19                 2          3     Life Sciences              24
# 20                11          2             Other              26
# 21                 9          4     Life Sciences              27
# 22                 7          4     Life Sciences              28
# 23                15          2     Life Sciences              30
# 24                 6          1           Medical              31
# 25                 5          3             Other              32
# 26                16          1     Life Sciences              33
# 27                 8          4         Marketing              35
# 28                 7          4           Medical              36
# 29                 2          4         Marketing              38
# 30                 2          3           Medical              39
# 31                10          4             Other              40
# 32                 9          2           Medical              41
# 33                 5          3  Technical Degree              42
# 34                 1          3           Medical              45
# 35                 2          2           Medical              46
# 36                 3          2         Marketing              47
# 37                 2          3         Marketing              49
# 38                 5          4     Life Sciences              51
# 39                 1          3     Life Sciences              52
# 40                 4          2             Other              53
# 41                 2          4     Life Sciences              54
# 42                25          3     Life Sciences              55
# 43                 8          3     Life Sciences              56
# 44                 1          2           Medical              57
# 45                12          3  Technical Degree              58
# 46                23          4         Marketing              60
# 47                19          2     Life Sciences              61
# 48                 5          4         Marketing              62
# 49                 8          1     Life Sciences              63
# 50                 1          2     Life Sciences              64
# 51                 5          4  Technical Degree              65
# 52                 1          5         Marketing              68
# 53                11          2           Medical              70
# 54                23          3         Marketing              72
# 55                 1          2     Life Sciences              73
# 56                18          5     Life Sciences              74
# 57                23          4           Medical              75
# 58                 7          4     Life Sciences              76
# 59                 1          4     Life Sciences              77
#
#     EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                         2  ...                 3                         1
# 1                         3  ...                 4                         4
# 2                         4  ...                 3                         2
# 3                         4  ...                 3                         3
# 4                         1  ...                 3                         4
# 5                         4  ...                 3                         3
# 6                         3  ...                 4                         1
# 7                         4  ...                 4                         2
# 8                         4  ...                 4                         2
# 9                         3  ...                 3                         2
# 10                        1  ...                 3                         3
# 11                        4  ...                 3                         4
# 12                        1  ...                 3                         4
# 13                        2  ...                 3                         3
# 14                        3  ...                 3                         2
# 15                        2  ...                 3                         3
# 16                        1  ...                 3                         4
# 17                        4  ...                 3                         2
# 18                        1  ...                 3                         3
# 19                        4  ...                 3                         3
# 20                        1  ...                 3                         4
# 21                        3  ...                 4                         2
# 22                        1  ...                 3                         3
# 23                        3  ...                 3                         4
# 24                        2  ...                 3                         3
# 25                        3  ...                 3                         4
# 26                        2  ...                 4                         2
# 27                        3  ...                 3                         4
# 28                        1  ...                 3                         4
# 29                        2  ...                 3                         4
# 30                        3  ...                 3                         4
# 31                        4  ...                 3                         4
# 32                        4  ...                 3                         1
# 33                        4  ...                 3                         3
# 34                        2  ...                 3                         1
# 35                        4  ...                 3                         4
# 36                        1  ...                 3                         3
# 37                        4  ...                 3                         1
# 38                        2  ...                 3                         4
# 39                        3  ...                 3                         1
# 40                        3  ...                 3                         3
# 41                        4  ...                 3                         4
# 42                        1  ...                 3                         3
# 43                        4  ...                 3                         4
# 44                        3  ...                 4                         4
# 45                        2  ...                 3                         4
# 46                        2  ...                 4                         3
# 47                        2  ...                 4                         1
# 48                        1  ...                 4                         3
# 49                        4  ...                 3                         4
# 50                        1  ...                 3                         4
# 51                        3  ...                 3                         3
# 52                        2  ...                 4                         3
# 53                        3  ...                 3                         3
# 54                        3  ...                 3                         3
# 55                        1  ...                 3                         3
# 56                        2  ...                 4                         4
# 57                        3  ...                 3                         3
# 58                        4  ...                 4                         4
# 59                        1  ...                 3                         3
#
#     StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 0                  0                  8                     0
# 1                  1                 10                     3
# 2                  0                  7                     3
# 3                  0                  8                     3
# 4                  1                  6                     3
# 5                  0                  8                     2
# 6                  3                 12                     3
# 7                  1                  1                     2
# 8                  0                 10                     2
# 9                  2                 17                     3
# 10                 1                  6                     5
# 11                 0                 10                     3
# 12                 1                  5                     1
# 13                 1                  3                     2
# 14                 0                  6                     4
# 15                 1                 10                     1
# 16                 2                  7                     5
# 17                 2                  1                     2
# 18                 0                 31                     3
# 19                 0                  6                     3
# 20                 1                  5                     5
# 21                 0                 10                     4
# 22                 0                 13                     4
# 23                 0                  0                     6
# 24                 0                  8                     2
# 25                 1                 26                     3
# 26                 0                 10                     5
# 27                 1                 10                     2
# 28                 1                 24                     4
# 29                 0                 22                     2
# 30                 0                  7                     3
# 31                 0                  9                     5
# 32                 0                 10                     5
# 33                 1                 19                     6
# 34                 1                  6                     2
# 35                 2                  6                     3
# 36                 0                  3                     2
# 37                 0                  2                     3
# 38                 1                  6                     3
# 39                 2                 10                     3
# 40                 1                  1                     3
# 41                 1                  1                     6
# 42                 0                  1                     2
# 43                 0                  9                     0
# 44                 0                 12                     2
# 45                 0                 23                     0
# 46                 0                 10                     2
# 47                 0                  8                     1
# 48                 0                 14                     4
# 49                 0                  1                     2
# 50                 0                 23                     2
# 51                 0                  2                     3
# 52                 1                  9                     2
# 53                 1                 10                     3
# 54                 1                  5                     2
# 55                 0                 15                     1
# 56                 1                  9                     3
# 57                 1                  4                     3
# 58                 1                 10                     3
# 59                 1                  7                     2
#
#     WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                 1              6                   4
# 1                 3             10                   7
# 2                 3              0                   0
# 3                 3              8                   7
# 4                 3              2                   2
# 5                 2              7                   7
# 6                 2              1                   0
# 7                 3              1                   0
# 8                 3              9                   7
# 9                 2              7                   7
# 10                3              5                   4
# 11                3              9                   5
# 12                2              5                   2
# 13                3              2                   2
# 14                3              4                   2
# 15                3             10                   9
# 16                2              6                   2
# 17                2              1                   0
# 18                3             25                   8
# 19                3              3                   2
# 20                2              4                   2
# 21                3              5                   3
# 22                3             12                   6
# 23                3              0                   0
# 24                3              4                   2
# 25                2             14                  13
# 26                3             10                   2
# 27                3              9                   7
# 28                3             22                   6
# 29                2              2                   2
# 30                3              1                   1
# 31                4              4                   2
# 32                3             10                   0
# 33                4              1                   0
# 34                2              2                   0
# 35                2              5                   3
# 36                3              3                   2
# 37                3              2                   2
# 38                4              1                   1
# 39                3              5                   3
# 40                3              1                   0
# 41                3              1                   0
# 42                2              1                   0
# 43                3              9                   8
# 44                3             12                   8
# 45                3             22                  15
# 46                3              9                   5
# 47                3              1                   0
# 48                3              9                   6
# 49                3              1                   0
# 50                3              1                   0
# 51                2              2                   2
# 52                2              4                   3
# 53                3              4                   0
# 54                2              2                   2
# 55                3             15                  14
# 56                2              9                   8
# 57                3              2                   2
# 58                2              7                   7
# 59                4              7                   5
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 0                         0                     5
# 1                         1                     7
# 2                         0                     0
# 3                         3                     0
# 4                         2                     2
# 5                         3                     6
# 6                         0                     0
# 7                         0                     0
# 8                         1                     8
# 9                         7                     7
# 10                        0                     3
# 11                        0                     8
# 12                        4                     3
# 13                        1                     2
# 14                        0                     3
# 15                        8                     8
# 16                        0                     5
# 17                        0                     0
# 18                        3                     7
# 19                        1                     2
# 20                        1                     3
# 21                        0                     3
# 22                        2                    11
# 23                        0                     0
# 24                        1                     3
# 25                        4                     8
# 26                        6                     7
# 27                        4                     2
# 28                        5                    17
# 29                        2                     1
# 30                        0                     0
# 31                        1                     3
# 32                        1                     8
# 33                        0                     0
# 34                        2                     0
# 35                        1                     4
# 36                        0                     2
# 37                        2                     2
# 38                        0                     0
# 39                        1                     3
# 40                        0                     0
# 41                        0                     0
# 42                        0                     1
# 43                        1                     7
# 44                        3                     7
# 45                       15                     8
# 46                        8                     7
# 47                        0                     0
# 48                        0                     8
# 49                        0                     1
# 50                        0                     0
# 51                        2                     2
# 52                        1                     3
# 53                        2                     3
# 54                        0                     0
# 55                        8                    12
# 56                        1                     8
# 57                        2                     2
# 58                        1                     7
# 59                        0                     7
#
# [60 rows x 32 columns]

# %%
ordinal_features = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction',
                    'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
data[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0          2                        2               3                4
# 1          1                        3               2                2
# 2          2                        4               2                3
# 3          4                        4               3                3
# 4          1                        1               3                2
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                  3                         1                1
# 1                  4                         4                3
# 2                  3                         2                3
# 3                  3                         3                3
# 4                  3                         4                3

# %%
edu_map={1:'Below College', 2: 'College', 3:'Bachelor', 4:'Master', 5:'Doctor'}
plt.figure(figsize=(12,5))
sns.countplot(x=df['Education'].map(edu_map), hue='Attrition', data=df)
plt.title("Education and Attrition")
plt.show()

# %% [markdown]
# # Label Encoding

# %% [markdown]
# ###### Label Encoding is a technique that is used to convert categorical columns into numerical ones so that they can be fitted by machine learning models which only take numerical data. It is an important pre-processing step in a machine-learning project.

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# 1                        3  ...                 4                         4
# 2                        4  ...                 3                         2
# 3                        4  ...                 3                         3
# 4                        1  ...                 3                         4
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
# 2                 0                  7                     3                3
# 3                 0                  8                     3                3
# 4                 1                  6                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              6                   4                        0
# 1             10                   7                        1
# 2              0                   0                        0
# 3              8                   7                        3
# 4              2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 32 columns]

# %%
#Target Variable 
df['Attrition'] = df['Attrition'].replace({'No':0, 'Yes':1})
# Out:
# C:\Users\nehar\AppData\Local\Temp\ipykernel_21972\3397525731.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Attrition'] = df['Attrition'].replace({'No':0, 'Yes':1})

# %%
#encoding binary variable
df['OverTime']=df['OverTime'].map({'No':0, 'Yes':1})
df['Gender']=df['Gender'].map({'Male':0, 'Female':1})

# %%
data['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %% [markdown]
# ###### Since, we cannot define a numerical representation of JobRole, so instead of binary encoding we perform label encoding

# %%
#encodeing categorical columns taht are ordinal 
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']
label_encoders={}
for column in encoding_cols:
    label_encoders[column] =LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0          2               1               1                        2  ...
# 1          1               1               2                        3  ...
# 2          2               4               4                        4  ...
# 3          4               1               5                        4  ...
# 4          1               3               7                        1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
#  14  JobRole                   1470 non-null   object
#  15  JobSatisfaction           1470 non-null   int64
#  16  MaritalStatus             1470 non-null   object
#  17  MonthlyIncome             1470 non-null   int64
#  18  MonthlyRate               1470 non-null   int64
#  19  NumCompaniesWorked        1470 non-null   int64
#  20  OverTime                  1470 non-null   object
#  21  PercentSalaryHike         1470 non-null   int64
#  22  PerformanceRating         1470 non-null   int64
#  23  RelationshipSatisfaction  1470 non-null   int64
#  24  StockOptionLevel          1470 non-null   int64
#  25  TotalWorkingYears         1470 non-null   int64
#  26  TrainingTimesLastYear     1470 non-null   int64
#  27  WorkLifeBalance           1470 non-null   int64
#  28  YearsAtCompany            1470 non-null   int64
#  29  YearsInCurrentRole        1470 non-null   int64
#  30  YearsSinceLastPromotion   1470 non-null   int64
#  31  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(24), object(8)
# memory usage: 367.6+ KB

# %% [markdown]
# ### The data is all numeric value
